# %%
print("spark version", spark.version)
# Out:
# spark version 4.1.0

# %%
import random 
import pandas as pd

# %%
first_names = [
    "Sahib", "Nakul", "Anisha", "Binil", "Harmanjit",
    "Aman", "Karan", "Simran", "Priya", "Rahul"
]

last_names = [
    "Singh", "Yadav", "Chaudhary", "John", "Patel",
    "Sharma", "Kaur", "Brown", "Wilson", "Taylor"
]

# %%
first_name  = random.choice(first_names)
last_name = random.choice(last_names)
full_name = first_name + " " + last_name
print(full_name)
# Out:
# Priya Taylor

# %%
for i in range(100):
    first_name  = random.choice(first_names)
    last_name = random.choice(last_names)
    full_name = first_name + " " + last_name
    print(full_name)
# Out:
# Harmanjit Wilson
# Simran Wilson
# Rahul John
# Rahul Brown
# Karan Chaudhary
# Priya Chaudhary
# Simran Brown
# Rahul John
# Rahul Yadav
# Nakul Singh
# Priya John
# Sahib Yadav
# Priya Patel
# Aman Brown
# Rahul John
# Rahul Taylor
# Karan Wilson
# Priya Singh
# Simran John
# Binil Wilson
# Anisha Singh
# Simran Brown
# Rahul Sharma
# Harmanjit Wilson
# Harmanjit Kaur
# Rahul Singh
# Rahul Chaudhary
# Priya Patel
# Aman Sharma
# Binil Singh
# Binil Kaur
# Nakul Yadav
# Rahul Taylor
# Karan Singh
# Anisha Chaudhary
# Rahul Singh
# Anisha Brown
# Nakul Yadav
# Anisha Chaudhary
# Rahul Sharma
# Rahul Brown
# Harmanjit Yadav
# Priya Singh
# Binil Brown
# Nakul Chaudhary
# Nakul Taylor
# Rahul Wilson
# Sahib Chaudhary
# Sahib Taylor
# Harmanjit Kaur
# Aman Kaur
# Sahib Singh
# Priya Singh
# Priya Taylor
# Karan Yadav
# Karan Taylor
# Aman John
# Sahib Wilson
# Simran Brown
# Anisha Singh
# Anisha Yadav
# Rahul Sharma
# Aman Sharma
# Harmanjit Wilson
# Karan Singh
# Binil Singh
# ...

# %%
for i in range(100):

    user_id = i + 1

    first_name = random.choice(first_names)
    last_name = random.choice(last_names)

    full_name = first_name + " " + last_name

    print(user_id, full_name)
# Out:
# 1 Rahul Brown
# 2 Aman Taylor
# 3 Sahib Kaur
# 4 Aman Kaur
# 5 Aman Chaudhary
# 6 Harmanjit Chaudhary
# 7 Nakul Sharma
# 8 Priya Yadav
# 9 Binil Yadav
# 10 Harmanjit Yadav
# 11 Sahib Taylor
# 12 Nakul Taylor
# 13 Harmanjit Patel
# 14 Nakul Yadav
# 15 Harmanjit Patel
# 16 Binil Yadav
# 17 Anisha Kaur
# 18 Nakul Chaudhary
# 19 Karan Kaur
# 20 Nakul Sharma
# 21 Rahul Chaudhary
# 22 Priya Brown
# 23 Simran Brown
# 24 Karan Yadav
# 25 Sahib Chaudhary
# 26 Anisha Singh
# 27 Simran John
# 28 Priya Taylor
# 29 Aman Wilson
# 30 Simran Sharma
# 31 Priya John
# 32 Aman Kaur
# 33 Karan Yadav
# 34 Sahib Chaudhary
# 35 Karan Taylor
# 36 Binil Taylor
# 37 Sahib Wilson
# 38 Simran Yadav
# 39 Priya Sharma
# 40 Harmanjit Yadav
# 41 Simran John
# 42 Sahib Brown
# 43 Sahib Patel
# 44 Binil Brown
# 45 Anisha Kaur
# 46 Anisha Sharma
# 47 Simran Wilson
# 48 Nakul Patel
# 49 Harmanjit Brown
# 50 Rahul Singh
# 51 Rahul Taylor
# 52 Nakul Sharma
# 53 Karan Taylor
# 54 Binil Yadav
# 55 Aman Sharma
# ...

# %%
users = []

for i in range(100):
    user_id = i + 1

    first_name = random.choice(first_names)
    last_name = random.choice(last_names)
    full_name = first_name + " " + last_name

    users.append([user_id, full_name])

print(users)
# Out:
# [[1, 'Harmanjit Sharma'], [2, 'Nakul Yadav'], [3, 'Rahul Taylor'], [4, 'Karan Brown'], [5, 'Rahul Yadav'], [6, 'Anisha Singh'], [7, 'Binil Taylor'], [8, 'Binil Chaudhary'], [9, 'Binil John'], [10, 'Nakul John'], [11, 'Nakul Singh'], [12, 'Nakul Sharma'], [13, 'Nakul Chaudhary'], [14, 'Sahib Singh'], [15, 'Priya Brown'], [16, 'Sahib Taylor'], [17, 'Rahul Singh'], [18, 'Binil Singh'], [19, 'Anisha Chaudhary'], [20, 'Harmanjit Chaudhary'], [21, 'Priya Brown'], [22, 'Aman Yadav'], [23, 'Nakul Yadav'], [24, 'Simran Patel'], [25, 'Anisha Singh'], [26, 'Binil Patel'], [27, 'Karan Chaudhary'], [28, 'Nakul Patel'], [29, 'Harmanjit Yadav'], [30, 'Nakul John'], [31, 'Rahul Yadav'], [32, 'Aman Yadav'], [33, 'Anisha John'], [34, 'Aman Kaur'], [35, 'Rahul Patel'], [36, 'Rahul Singh'], [37, 'Anisha Singh'], [38, 'Binil John'], [39, 'Karan Patel'], [40, 'Binil Patel'], [41, 'Rahul Kaur'], [42, 'Aman Taylor'], [43, 'Anisha Patel'], [44, 'Binil Brown'], [45, 'Priya Patel'], [46, 'Aman Kaur'], [47, 'An
# ...

# %%
Departments = [
    "IT",
    "Finance",
    "HR",
    "Security",
    "Sales",
    "Marketing",
    "Cloud",
    "Engineering"
]

# %%
users = []

for i in range(100):
    user_id = i + 1

    first_name = random.choice(first_names)
    last_name = random.choice(last_names)
    full_name = first_name + " " + last_name
    department = random.choice(Departments)

    users.append([user_id, full_name, department])

print(users)
# Out:
# [[1, 'Sahib Taylor', 'Finance'], [2, 'Sahib Wilson', 'Cloud'], [3, 'Harmanjit Singh', 'Security'], [4, 'Karan Yadav', 'Cloud'], [5, 'Anisha Chaudhary', 'HR'], [6, 'Harmanjit Taylor', 'Finance'], [7, 'Aman Chaudhary', 'Engineering'], [8, 'Binil Kaur', 'Cloud'], [9, 'Sahib Patel', 'Marketing'], [10, 'Simran Brown', 'Security'], [11, 'Priya Wilson', 'Security'], [12, 'Nakul John', 'Engineering'], [13, 'Harmanjit Patel', 'HR'], [14, 'Karan Brown', 'Sales'], [15, 'Harmanjit Singh', 'Sales'], [16, 'Simran Brown', 'Finance'], [17, 'Harmanjit Patel', 'IT'], [18, 'Harmanjit Chaudhary', 'Finance'], [19, 'Harmanjit Taylor', 'Security'], [20, 'Harmanjit Brown', 'Marketing'], [21, 'Binil Kaur', 'IT'], [22, 'Karan Yadav', 'Finance'], [23, 'Binil Taylor', 'Security'], [24, 'Aman Taylor', 'Sales'], [25, 'Anisha Singh', 'Finance'], [26, 'Rahul Taylor', 'Cloud'], [27, 'Priya Singh', 'IT'], [28, 'Harmanjit Taylor', 'IT'], [29, 'Priya Chaudhary', 'Engineering'], [30, 'Simran Taylor', 'IT'], [31, 'Priya 
# ...

# %%
df = pd.DataFrame(users, columns=["UserID", "UserName", "Department"])
print(df)
display(df)
# Out:
#     UserID          UserName Department
# 0        1      Sahib Taylor    Finance
# 1        2      Sahib Wilson      Cloud
# 2        3   Harmanjit Singh   Security
# 3        4       Karan Yadav      Cloud
# 4        5  Anisha Chaudhary         HR
# ..     ...               ...        ...
# 95      96       Binil Patel   Security
# 96      97  Anisha Chaudhary         IT
# 97      98  Harmanjit Sharma      Cloud
# 98      99      Karan Wilson         HR
# 99     100  Anisha Chaudhary         HR
#
# [100 rows x 3 columns]
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
import random
import pandas as pd

first_names = [ "Sahib", "Nakul", "Anisha", "Binil", "Harmanjit",
    "Aman", "Karan", "Simran", "Priya", "Rahul"]
last_names = ["Singh", "Yadav", "Chaudhary", "John", "Patel",
    "Sharma", "Kaur", "Brown", "Wilson", "Taylor"]

departments = [ "IT",
    "Finance",
    "HR",
    "Security",
    "Sales",
    "Marketing",
    "Cloud",
    "Engineering"]

countries = ["Canada", "USA", "India", "UK"]

account_statuses = ["Active", "Inactive"]

users = []

for i in range(100):

    user_id = i + 1

    first_name = random.choice(first_names)
    last_name = random.choice(last_names)

    full_name = first_name + " " + last_name

    department = random.choice(departments)

    country = random.choices(
        countries,
        weights=[75,10,10,5]
    )[0]

    account_status = random.choices(
        account_statuses,
        weights=[90,10]
    )[0]

    users.append([user_id, full_name, department, country, account_status])

df = pd.DataFrame(users, columns=["UserID", "UserName", "Department", "Country", "AccountStatus"])
print(df)
# Out:
#     UserID             UserName   Department Country AccountStatus
# 0        1          Nakul Brown  Engineering      UK        Active
# 1        2        Anisha Sharma      Finance  Canada        Active
# 2        3  Harmanjit Chaudhary      Finance     USA        Active
# 3        4           Nakul John     Security  Canada        Active
# 4        5         Simran Brown      Finance  Canada        Active
# ..     ...                  ...          ...     ...           ...
# 95      96         Karan Taylor        Sales  Canada        Active
# 96      97      Nakul Chaudhary     Security     USA        Active
# 97      98         Karan Wilson    Marketing  Canada        Active
# 98      99          Simran Kaur  Engineering  Canada        Active
# 99     100          Nakul Brown        Cloud  Canada        Active
#
# [100 rows x 5 columns]

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.shape
# Out:
# (100, 5)

# %%
df.shape[0]
# Out:
# 100

# %%
df["UserName"].duplicated().sum()
# Out:
# np.int64(35)

# %%
df["UserID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Country"].value_counts()
# Out:
# Country
# Canada    74
# USA       14
# India      8
# UK         4
# Name: count, dtype: int64

# %%
df["Country"].value_counts(normalize=True) * 100
# Out:
# Country
# Canada    74.0
# USA       14.0
# India      8.0
# UK         4.0
# Name: proportion, dtype: float64

# %%
df["AccountStatus"].value_counts()
# Out:
# AccountStatus
# Active      91
# Inactive     9
# Name: count, dtype: int64

# %%
df["AccountStatus"].value_counts(normalize=True) * 100
# Out:
# AccountStatus
# Active      91.0
# Inactive     9.0
# Name: proportion, dtype: float64

# %%
df.to_csv("users.csv", index = False)

# %%
import os

print(os.getcwd())
# Out:
# /Workspace/Users/sin20010@sheridancollege.ca/AI_Cybersecurity_Threat_Monitoring_System

# %%
os.listdir()
# Out:
# ['devices.csv',
#  'cyber_threat_alerts.csv',
#  '01_Create_Synthetic_Data.ipynb',
#  'users.csv',
#  'login_logs.csv']

# %%
devices = []

device_types = ["Laptop", "Desktop", "Mobile", "Tablet"]
operating_systems = ["Windows", "macOS", "Linux", "Android", "iOS"]
trust_devices = ["Trusted", "Untrusted"]

for i in range(150):

    device_id = i + 1
    user_id = random.randint(1, 100)
    device_type = random.choice(device_types)

    if device_type == "Laptop":
        operating_system = random.choice(["Windows", "macOS", "Linux"])

    elif device_type == "Desktop":
        operating_system = random.choice(["Windows", "macOS", "Linux"])

    elif device_type == "Mobile":
        operating_system = random.choice(["Android", "iOS"])

    else:
        operating_system = random.choice(["Android", "iPadOS"])

    trust_device = random.choices(trust_devices, weights=[90, 10])[0]

    devices.append([
        device_id,
        user_id,
        device_type,
        operating_systems,
        trust_device
    ])

devices_df = pd.DataFrame(
    devices,
    columns=[
        "DeviceID",
        "UserID",
        "DeviceType",
        "OperatingSystem",
        "TrustDevice"
    ]
)

display(devices_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
devices_df.shape
# Out:
# (150, 5)

# %%
devices_df.to_csv("devices.csv", index = False)

# %%
os.listdir()
# Out:
# ['devices.csv',
#  'cyber_threat_alerts.csv',
#  '01_Create_Synthetic_Data.ipynb',
#  'users.csv',
#  'login_logs.csv']

# %%
# login logs dataset 
login_logs = []
from datetime import datetime, timedelta
login_methods =["Password","MFA","SSO"]
login_statuses = ["Success","Failure"]
risk_levels = ["Low","Medium","High"]
login_countries = ["Canada","USA","India","UK"]
start_date = datetime(2026, 1, 1)
for i in range(500):
    login_id = i+1
    selected_device = devices_df.sample(1).iloc[0]
    user_id = selected_device["UserID"]
    device_id = selected_device["DeviceID"]
    random_days = random.randint(0, 180)
    random_hours = random.randint(0, 23)
    random_minutes = random.randint(0, 59)

    login_time = start_date + timedelta(
        days=random_days,
        hours=random_hours,
        minutes=random_minutes
    )

    ip_address = ".".join([
        str(random.randint(1, 255)),
        str(random.randint(0, 255)),
        str(random.randint(0, 255)),
        str(random.randint(1, 255))
    ])

    country = random.choice(login_countries)
    login_method = random.choice(login_methods)
    
    login_status = random.choices(
    login_statuses,
    weights=[90, 10])[0]

    risk_level = random.choices(
    risk_levels,
    weights=[70, 20, 10])[0]

    login_logs.append([
        login_id,
        user_id,
        device_id,
        login_time,
        ip_address,
        country,
        login_method,
        login_status,
        risk_level
    ])

login_logs_df = pd.DataFrame(
    login_logs,
    columns=[
        "LoginID",
        "UserID",
        "DeviceID",
        "LoginTime",
        "IPAddress",
        "Country",
        "LoginMethod",
        "LoginStatus",
        "RiskLevel"
    ]
)

display(login_logs_df)
login_logs_df.to_csv("login_logs.csv", index = False)
os.listdir()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
login_logs_df.shape
# Out:
# (500, 9)

# %%
#  4 th data set cyber alert
alerts = []
alert_id = 1
for index, row in login_logs_df.iterrows():
    if row["RiskLevel"] == "High" and row["LoginStatus"] == "Failure":
        alerts.append([
        alert_id,
        row["LoginID"],
        row["UserID"],
        "Brute Force",
        "High"
        ])
    elif row["RiskLevel"] == "High" and row["LoginStatus"] == "Success":
        alerts.append([
        alert_id,
        row["LoginID"],
        row["UserID"],
        "Suspicious Login",
        "High"
    ])   
        alert_id += 1
alerts_df = pd.DataFrame(
    alerts,
    columns=[
        "AlertID",
        "LoginID",
        "UserID",
        "AlertType",  
        "AlertSeverity"
    ]
)
display(alerts_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
alerts_df.shape
# Out:
# (55, 5)

# %%
alerts_df.to_csv("cyber_threat_alerts.csv", index=False)

# %%
os.listdir()
