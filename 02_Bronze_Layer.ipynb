# %%
users_df = spark.read.csv(
    "/Workspace/Users/biniljohn34674@gmail.com/term project/users.csv",
    header=True,
    inferSchema=True
)

# %%
users_df.show()
# Out:
# +------+----------------+----------+-------+-------------+
# |UserID|        UserName|Department|Country|AccountStatus|
# +------+----------------+----------+-------+-------------+
# |     1|   Simran Sharma| Marketing| Canada|       Active|
# |     2|      Sahib Kaur| Marketing| Canada|     Inactive|
# |     3| Sahib Chaudhary|        IT| Canada|     Inactive|
# |     4|Harmanjit Wilson|     Sales| Canada|       Active|
# |     5|     Aman Taylor|        HR|  India|       Active|
# |     6|    Karan Taylor|        HR| Canada|       Active|
# |     7|  Harmanjit Kaur|     Sales| Canada|       Active|
# |     8|      Rahul John|   Finance|    USA|       Active|
# |     9|     Karan Singh|     Sales| Canada|     Inactive|
# |    10|      Aman Singh|        HR| Canada|       Active|
# |    11|     Aman Sharma|     Cloud| Canada|       Active|
# |    12|    Simran Brown|   Finance| Canada|     Inactive|
# |    13| Priya Chaudhary|  Security| Canada|       Active|
# ...

# %%
users_df.printSchema()
# Out:
# root
#  |-- UserID: integer (nullable = true)
#  |-- UserName: string (nullable = true)
#  |-- Department: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- AccountStatus: string (nullable = true)

# %%
users_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.default.bronze_users")

# %%
spark.sql("""
SELECT *
FROM workspace.default.bronze_users
""").show()
# Out:
# +------+----------------+----------+-------+-------------+
# |UserID|        UserName|Department|Country|AccountStatus|
# +------+----------------+----------+-------+-------------+
# |     1|   Simran Sharma| Marketing| Canada|       Active|
# |     2|      Sahib Kaur| Marketing| Canada|     Inactive|
# |     3| Sahib Chaudhary|        IT| Canada|     Inactive|
# |     4|Harmanjit Wilson|     Sales| Canada|       Active|
# |     5|     Aman Taylor|        HR|  India|       Active|
# |     6|    Karan Taylor|        HR| Canada|       Active|
# |     7|  Harmanjit Kaur|     Sales| Canada|       Active|
# |     8|      Rahul John|   Finance|    USA|       Active|
# |     9|     Karan Singh|     Sales| Canada|     Inactive|
# |    10|      Aman Singh|        HR| Canada|       Active|
# |    11|     Aman Sharma|     Cloud| Canada|       Active|
# |    12|    Simran Brown|   Finance| Canada|     Inactive|
# |    13| Priya Chaudhary|  Security| Canada|       Active|
# ...

# %%
devices_df = spark.read.csv(
    "/Workspace/Users/biniljohn34674@gmail.com/term project/devices.csv",
    header=True,
    inferSchema=True
)

# %%
devices_df.show()
devices_df.printSchema()
# Out:
# +--------+------+----------+--------------------+-----------+
# |DeviceID|UserID|DeviceType|     OperatingSystem|TrustDevice|
# +--------+------+----------+--------------------+-----------+
# |       1|    89|   Desktop|['Windows', 'macO...|    Trusted|
# |       2|    36|   Desktop|['Windows', 'macO...|    Trusted|
# |       3|    26|    Laptop|['Windows', 'macO...|    Trusted|
# |       4|     5|    Tablet|['Windows', 'macO...|    Trusted|
# |       5|    42|    Tablet|['Windows', 'macO...|    Trusted|
# |       6|    99|    Mobile|['Windows', 'macO...|    Trusted|
# |       7|    62|    Tablet|['Windows', 'macO...|    Trusted|
# |       8|    87|    Laptop|['Windows', 'macO...|  Untrusted|
# |       9|    30|    Tablet|['Windows', 'macO...|    Trusted|
# |      10|    18|    Mobile|['Windows', 'macO...|  Untrusted|
# |      11|    35|    Laptop|['Windows', 'macO...|    Trusted|
# |      12|    47|    Laptop|['Windows', 'macO...|    Trusted|
# ...

# %%
devices_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.default.bronze_devices")

# %%
login_logs_df = spark.read.csv(
    "/Workspace/Users/biniljohn34674@gmail.com/term project/login_logs.csv",
    header=True,
    inferSchema=True
)

# %%
login_logs_df.show()
login_logs_df.printSchema()
# Out:
# +-------+------+--------+-------------------+---------------+-------+-----------+-----------+---------+
# |LoginID|UserID|DeviceID|          LoginTime|      IPAddress|Country|LoginMethod|LoginStatus|RiskLevel|
# +-------+------+--------+-------------------+---------------+-------+-----------+-----------+---------+
# |      1|    34|     118|2026-01-21 04:32:00|   85.189.1.164|     UK|   Password|    Success|      Low|
# |      2|    99|     126|2026-05-13 08:02:00|235.133.230.165|  India|        MFA|    Success|     High|
# |      3|     5|      94|2026-01-17 16:53:00|    75.130.18.3|    USA|        SSO|    Success|      Low|
# |      4|    30|      40|2026-06-15 07:02:00| 182.246.119.71|    USA|        SSO|    Success|   Medium|
# |      5|    35|      11|2026-05-13 15:52:00| 167.247.166.85|     UK|   Password|    Failure|   Medium|
# |      6|    62|      37|2026-06-11 22:05:00|  78.223.102.58|    USA|        MFA|    Success|   Medium|
# ...

# %%
login_logs_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.default.bronze_login_logs")

# %%
alerts_df = spark.read.csv(
    "/Workspace/Users/biniljohn34674@gmail.com/term project/cyber_threat_alerts.csv",
    header=True,
    inferSchema=True
)

# %%
alerts_df.show()
alerts_df.printSchema()
# Out:
# +-------+-------+------+----------------+-------------+
# |AlertID|LoginID|UserID|       AlertType|AlertSeverity|
# +-------+-------+------+----------------+-------------+
# |      1|      2|    99|Suspicious Login|         High|
# |      2|     11|    47|Suspicious Login|         High|
# |      3|     14|    74|Suspicious Login|         High|
# |      4|     15|    42|Suspicious Login|         High|
# |      5|     20|    20|Suspicious Login|         High|
# |      6|     34|    42|Suspicious Login|         High|
# |      7|     35|    67|Suspicious Login|         High|
# |      8|     72|    84|Suspicious Login|         High|
# |      9|     78|     2|Suspicious Login|         High|
# |     10|     87|    91|Suspicious Login|         High|
# |     11|     90|    58|Suspicious Login|         High|
# |     12|     94|    87|Suspicious Login|         High|
# |     13|    104|   100|     Brute Force|         High|
# |     13|    108|    22|Suspicious Login|         High|
# ...

# %%
alerts_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.default.bronze_threat_alerts")

# %%
spark.sql("SHOW TABLES IN workspace.default").show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | default|      bronze_devices|      false|
# | default|   bronze_login_logs|      false|
# | default|bronze_threat_alerts|      false|
# | default|        bronze_users|      false|
# | default|      silver_devices|      false|
# | default|        silver_users|      false|
# +--------+--------------------+-----------+
